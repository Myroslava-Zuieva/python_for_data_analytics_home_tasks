# %% [markdown]
# 1. Скільки різних паролів можна скласти, використовуючи три літери англійського алфавіту, якщо літери не повинні повторюватися?
# 2. Є група з 8 людей. Скількома способами можна обрати комітет із 3 осіб?
# 3. Скількома різними способами можна розташувати на полиці 5 різних книг?
# 4. В урні знаходяться 4 червоні, 3 сині і 2 зелені кулі. Скількома способами можна витягти 3 кулі, якщо вони повинні бути різних кольорів?

# %% [raw]
# 1. Скільки різних паролів можна скласти, використовуючи три літери англійського алфавіту, якщо літери не повинні повторюватися?
#
# Якщо ми беремо не просто 3 різні літери англійського алфавіту, а усі можливі комбінації з 3 різних літер, тоді:
#
# Для першої літери є 26 варіантів, для другої — 25 (оскільки одна літера вже використана), а для третьої — 24.
#
# Кількість таких паролів:
#
# 26 * 25 * 24 = 15600
#
# 2. Є група з 8 людей. Скількома способами можна обрати комітет із 3 осіб?
#
# В цій задачі не важливий порядок людей, тому тут кількість комбінацій можна визначити за формулою:
#
# C(n, k) = $\frac{n!}{k!(n - k)!}$
#
# де  n = 8  — кількість людей,  k = 3  — кількість вибраних людей.
#
# Тоді кількість способів:
#
# C(8, 3) = $\frac {8!}{3!(8 - 3)!} = \frac{8 * 7 * 6}{3 * 2 * 1} = 56$
#
#
# 3. Скількома різними способами можна розташувати на полиці 5 різних книг?
#
# Тут потрібно переставити 5 різних книг. Кількість перестановок визначається як:
#
# P(n) = n!
#
# де  n = 5.
#
# Отже, кількість перестановок:
#
# 5! = 5 * 4 * 3 * 2 * 1 = 120
#
# 4. В урні знаходяться 4 червоні, 3 сині і 2 зелені кулі. Скількома способами можна витягти 3 кулі, якщо вони повинні бути різних кольорів?
#
# Оскільки кожна куля повинна бути різного кольору (червона, синя і зелена), потрібно вибрати по одній кулі кожного кольору:
#
# 	•	Вибір червоної кулі: 4 варіанти (оскільки є 4 червоні кулі).
# 	•	Вибір синьої кулі: 3 варіанти.
# 	•	Вибір зеленої кулі: 2 варіанти.
#
# Отже, кількість способів витягти кулі:
#
# 4 * 3 * 2 = 24
#
#
# Таким чином, можна витягти кулі 24 різними способами.
